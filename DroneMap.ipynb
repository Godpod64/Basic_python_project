# %%
import numpy as np
import pandas as pd

# %%
# Function to initiate program

def get_filename(file_type):
    while True:
        print('Enter the next route instructions, or enter Stop to finish:' + file_type)
        filename = input()
        try:
            with open(filename, 'r') as f:
               my_file = f.read()
            return my_file
        except FileNotFoundError:
            if filename == "STOP":
                return "STOP"
            else:
                print('File not found')
                
# Function to generate grid:

def display_grid(game, grid_size):
    c = 12
    x = 0
    l = "| X "
    sc = False  
  
    for i in range(grid_size):
        if i < 3:
            print(f"{(c-i)}", end='')
        elif i > 2:
            print(f"{(c-i)} ", end='')
        
        # Since y values correspond to indexes, the X values below link the y coordinates to the correct index so that y coordinates can be correctly plotted:

        for j in range(grid_size):
            for a, b in zip(x_coords, y_coords):
                if b == 12:
                    x = 12
                    if b == 12 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 11:
                    x = 10
                    if b == 11 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 10:
                    x = 8
                    if b == 10 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 9:
                    x = 6
                    if b == 9 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 8:
                    x = 4
                    if b == 8 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 7:
                    x = 2
                    if b == 7 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 6:
                    x = 0
                    if b == 6 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 5:
                    x = -2
                    if b == 5 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 4:
                    x = -4
                    if b == 4 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 3:
                    x = -6
                    if b == 3 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 2:
                    x = -8
                    if b == 2 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
                elif b == 1:
                    x = -10
                    if b == 1 and [(j+1), (x+i)] == [a, b]:
                        sc = True
                        print(l, end='')
            if sc == False:
                print(f"| {game} ", end='')
            sc = False
        print("| ")
        print((grid_size*4+4)*"-")
     
    print(f"  ", end='')
    for h in range(grid_size):
        if h < 9:
            print(f"| {h+1} ", end='')
        else:
            print(f"| {h+1}", end='')
    print("|")
    
    print("Coordinates:\n", allcoords)

# Function to format data:

while(True):
    x = get_filename('')
    if x=="STOP":
        break
    alldigits = x.split("\n")
    Starting_Coordinates = []
    Directions = []
    Vector = []
    Possible_coords = []
    coords = []

    for i in range(13):
            Possible_coords.append(str(i))

    for line in alldigits:
        if line in Possible_coords:
            Starting_Coordinates.append(line)
        else:
            Directions.append(line)
    # to remove the space (" ") from list (Directions) to create new list (Vectors):
    for direction in Directions:
        if direction.strip():
            Vector.append(direction)

    # To capture the starting xy coordinate as an integer: 
    place = [int(Starting_Coordinates[0]), int(Starting_Coordinates[1])]
    x_co = place[0]
    y_co = place[1]
    allcoords = []
    # for loop to generate list of coordinates:
    for direction in Vector:
        if direction == "N":
            a = [x_co, (y_co + 1)]
            allcoords.append(a)
            y_co += 1
        elif direction == "E":
            b = [(x_co + 1), y_co]
            allcoords.append(b)
            x_co += 1
        elif direction == "W":
            c = [(x_co - 1), y_co]
            allcoords.append(c)
            x_co -= 1
        elif direction == "S":
            d = [x_co, (y_co - 1)]
            allcoords.append(d)
            y_co -= 1
    
    # Separating x coordinates from y coordinates enables each coordinate to be linked to an index more easily, which enables the points to be plotted (they remain linked by iterating through the lists simulatneously using the zip function):
    
    x_coords = []
    y_coords = []

    for coord in allcoords:
        x_coords.append(coord[0])
        y_coords.append(coord[1])

    x_coords.insert(0, place[0])
    y_coords.insert(0, place[1])
    allcoords.insert(0, [place[0], place[1]])

    # The sequence below deals with coorindates that place outside of the grid:

    allcoordlist = True

    for xcoord in x_coords:
        if xcoord > 12 or xcoord < 1:
                allcoordlist = False

    for ycoord in y_coords:
        if ycoord > 12 or ycoord < 1:
                allcoordlist = False

    if allcoordlist == True:
        display_grid(' ', 12)
    else:
        print("Error: The route is outside of the grid")
# Out:
# Enter the next route instructions, or enter Stop to finish:
# 12|   |   | X |   |   |   |   |   |   |   |   |   |
# ----------------------------------------------------
# 11|   |   | X |   |   |   |   |   |   |   |   |   |
# ----------------------------------------------------
# 10|   | X | X |   |   | X | X | X |   |   |   |   |
# ----------------------------------------------------
# 9 |   | X |   |   |   | X |   | X | X |   |   |   |
# ----------------------------------------------------
# 8 |   | X |   |   |   | X | X |   | X | X |   |   |
# ----------------------------------------------------
# 7 |   | X | X | X | X |   | X |   |   | X |   |   |
# ----------------------------------------------------
# 6 |   |   |   |   | X |   | X |   | X | X |   |   |
# ----------------------------------------------------
# 5 |   |   | X | X | X |   | X |   | X |   |   |   |
# ----------------------------------------------------
# 4 |   |   | X | X | X | X | X |   | X |   |   |   |
# ...

# %%
pd.options.display.max_rows = 999
